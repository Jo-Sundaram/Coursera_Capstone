# %% [markdown]
# # Capstone Dummy Notebook
#
# ### This notebook contains the rough work of my Final Capstone Project. Here I will extract and clean data from various sources, perform various methods of exploratory analysis and draw any conclusions I find.

# %% [markdown]
# ### Data Requirements:
#
# * City census data of Toronto and New York City
# * Foursquare api location data

# %% [markdown]
# <h2><a id = "top"></a>Structure</h2>
#
# 1. <a href = "#item1"> Acquiring Census Data</a><br>
#
# 2. <a href = "#item2"> Acquiring Foursquare Data</a><br>
#
# 3. <a href = "#item3"> Creating a map of toronto </a><br>
#
# 4. <a href = "#item4"> Foursquare data for each Borough in Toronto</a><br>
#
# 5. <a href = "#item5"> Creating a Master Map </a><br>

# %%
# @hidden_cell
import pandas as pd
import numpy as np
import json # library to handle JSON files
import requests # library to handle requests
import io
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib as plt

# %% [markdown]
# <h2><a id = 'item1'></a> Acquiring Census Data of Toronto and New York</h2>

# %% [markdown]
# This is census data of the neighbourhood profiles in Toronto

# %%
url = 'https://ckan0.cf.opendata.inter.prod-toronto.ca/download_resource/ef0239b1-832b-4d0b-a1f3-4153e53b189e?format=csv'
tor_data = pd.read_csv(url)
tor_data
# Out:
#        _id                   Category  \
# 0        1  Neighbourhood Information
# 1        2  Neighbourhood Information
# 2        3                 Population
# 3        4                 Population
# 4        5                 Population
# ...    ...                        ...
# 2378  2379                   Mobility
# 2379  2380                   Mobility
# 2380  2381                   Mobility
# 2381  2382                   Mobility
# 2382  2383                   Mobility
#
#                                                  Topic  \
# 0                            Neighbourhood Information
# 1                            Neighbourhood Information
# 2                             Population and dwellings
# 3                             Population and dwellings
# 4                             Population and dwellings
# ...                                                ...
# 2378  Mobility status - Place of residence 5 years ago
# 2379  Mobility status - Place of residence 5 years ago
# 2380  Mobility status - Place of residence 5 years ago
# 2381  Mobility status - Place of residence 5 years ago
# 2382  Mobility status - Place of residence 5 years ago
#
#                          Data Source                    Characteristic  \
# 0                    City of Toronto              Neighbourhood Number
# 1                    City of Toronto              TSNS2020 Designation
# 2     Census Profile 98-316-X2016001                  Population, 2016
# 3     Census Profile 98-316-X2016001                  Population, 2011
# 4     Census Profile 98-316-X2016001       Population Change 2011-2016
# ...                              ...                               ...
# 2378  Census Profile 98-316-X2016001                          Migrants
# 2379  Census Profile 98-316-X2016001                 Internal migrants
# 2380  Census Profile 98-316-X2016001          Intraprovincial migrants
# 2381  Census Profile 98-316-X2016001          Interprovincial migrants
# 2382  Census Profile 98-316-X2016001                 External migrants
#
#      City of Toronto Agincourt North Agincourt South-Malvern West  \
# 0                NaN             129                          128
# 1                NaN  No Designation               No Designation
# 2          2,731,571          29,113                       23,757
# 3          2,615,060          30,279                       21,988
# 4              4.50%          -3.90%                        8.00%
# ...              ...             ...                          ...
# 2378         400,950           3,170                        3,145
# 2379         184,120             880                          980
# 2380         141,135             735                          760
# 2381          42,985             135                          220
# 2382         216,835           2,280                        2,170
#
#            Alderwood           Annex  ... Willowdale West  \
# 0                 20              95  ...              37
# 1     No Designation  No Designation  ...  No Designation
# 2             12,054          30,526  ...          16,936
# 3             11,904          29,177  ...          15,004
# 4              1.30%           4.60%  ...          12.90%
# ...              ...             ...  ...             ...
# 2378             925           6,390  ...           3,765
# 2379             680           3,930  ...           1,545
# 2380             615           2,630  ...           1,070
# 2381              70           1,310  ...             475
# 2382             245           2,460  ...           2,220
#
#      Willowridge-Martingrove-Richview  Woburn Woodbine Corridor  \
# 0                                   7     137                64
# 1                      No Designation     NIA    No Designation
# 2                              22,156  53,485            12,541
# 3                              21,343  53,350            11,703
# 4                               3.80%   0.30%             7.20%
# ...                               ...     ...               ...
# 2378                            2,270   7,260               985
# 2379                            1,110   1,720               610
# 2380                              960   1,400               350
# 2381                              150     335               250
# 2382                            1,175   5,540               395
#
#      Woodbine-Lumsden        Wychwood  Yonge-Eglinton  Yonge-St.Clair  \
# 0                  60              94             100              97
# 1      No Designation  No Designation  No Designation  No Designation
# 2               7,865          14,349          11,817          12,528
# 3               7,826          13,986          10,578          11,652
# 4               0.50%           2.60%          11.70%           7.50%
# ...               ...             ...             ...             ...
# 2378              620           1,350           2,425           2,310
# 2379              395             780           1,260           1,355
# 2380              320             570             970           1,025
# 2381               85             210             290             325
# 2382              220             575           1,160             955
#
#      York University Heights      Yorkdale-Glen Park
# 0                         27                      31
# 1                        NIA  Emerging Neighbourhood
# 2                     27,593                  14,804
# 3                     27,713                  14,687
# 4                     -0.40%                   0.80%
# ...                      ...                     ...
# 2378                   4,965                   1,345
# 2379                   1,700                     580
# 2380                   1,490                     445
# 2381                     195                     135
# 2382                   3,285                     775
#
# [2383 rows x 146 columns]

# %% [markdown]
# This is population data of New York

# %%
url2 = 'https://www.baruch.cuny.edu/nycdata/population-geography/population.htm'
#https://www.baruch.cuny.edu/nycdata/population-geography/pop-demography.htm
demo = pd.read_html(url2)
demo[0]
# Out:
#     0                                                  1   \
# 0  NaN                             Population & Geography
# 1  NaN  New York City and Greater Metropolitan Area  P...
# 2  NaN                                    Back to Section
# 3  NaN  The Estimated 2018 Population of New York City...
# 4  NaN                                             County
# 5  NaN                                             County
# 6  NaN                                                NYC
# 7  NaN                                              Bronx
# 8  NaN                                  Brooklyn  (Kings)
# 9  NaN                              Manhattan  (New York)
# 10 NaN                                             Queens
# 11 NaN                          Staten Island  (Richmond)
# 12 NaN                                              Total
# 13 NaN                                                NaN
# 14 NaN                                     New York State
# 15 NaN                                             Nassau
# 16 NaN                                             Putnam
# 17 NaN                                           Rockland
# 18 NaN                                            Suffolk
# 19 NaN                                        Westchester
# 20 NaN                                              Total
# 21 NaN                                                NaN
# 22 NaN                           New Jersey  Pennsylvania
# 23 NaN                                             Bergen
# 24 NaN                                              Essex
# 25 NaN                                             Hudson
# 26 NaN                                          Hunterdon
# 27 NaN                                          Middlesex
# 28 NaN                                           Monmouth
# 29 NaN                                             Morris
# 30 NaN                                              Ocean
# 31 NaN                                            Passaic
# 32 NaN                                           Somerset
# 33 NaN                                             Sussex
# 34 NaN                                              Union
# 35 NaN                                           Pike, PA
# 36 NaN                                              Total
# 37 NaN                                                NaN
# 38 NaN  Notes:  *Estimates are based on 2010 Census an...
# 39 NaN                                                NaN
# 40 NaN                                                NaN
# 41 NaN  View Additional Population Data for NYC:  Popu...
# 42 NaN  Source:  U.S. Census Bureau - American Communi...
# 43 NaN                                                NaN
#
#                                                    2   \
# 0                              Population & Geography
# 1   New York City and Greater Metropolitan Area  P...
# 2                                     Back to Section
# 3   The Estimated 2018 Population of New York City...
# 4                                                2000
# 5                                                2000
# 6                                                 NaN
# 7                                                1332
# 8                                                2466
# 9                                                1538
# 10                                               2229
# 11                                                444
# 12                                               8009
# 13                                                NaN
# 14                                                NaN
# 15                                               1335
# 16                                                 96
# 17                                                287
# 18                                               1419
# 19                                                924
# 20                                               4061
# 21                                                NaN
# 22                                                NaN
# 23                                                884
# 24                                                792
# 25                                                609
# 26                                                122
# 27                                                750
# 28                                                615
# 29                                                470
# 30                                                511
# 31                                                490
# 32                                                298
# 33                                                144
# 34                                                523
# 35                                                 46
# 36                                               6254
# 37                                                NaN
# 38  Notes:  *Estimates are based on 2010 Census an...
# 39                                                NaN
# 40                                                NaN
# 41  View Additional Population Data for NYC:  Popu...
# 42  Source:  U.S. Census Bureau - American Communi...
# 43                                                NaN
#
#                                                    3   \
# 0                              Population & Geography
# 1   New York City and Greater Metropolitan Area  P...
# 2                                     Back to Section
# 3   The Estimated 2018 Population of New York City...
# 4                                                2010
# 5                                                2010
# 6                                                 NaN
# 7                                                1387
# 8                                                2510
# 9                                                1589
# 10                                               2235
# 11                                                470
# 12                                               8190
# 13                                                NaN
# 14                                                NaN
# 15                                               1342
# 16                                                100
# 17                                                313
# 18                                               1495
# 19                                                951
# 20                                               4200
# 21                                                NaN
# 22                                                NaN
# 23                                                906
# 24                                                784
# 25                                                636
# 26                                                127
# 27                                                811
# 28                                                630
# 29                                                578
# 30                                                578
# 31                                                502
# 32                                                324
# 33                                                149
# 34                                                538
# 35                                                 57
# 36                                               6535
# 37                                                NaN
# 38  Notes:  *Estimates are based on 2010 Census an...
# 39                                                NaN
# 40                                                NaN
# 41  View Additional Population Data for NYC:  Popu...
# 42  Source:  U.S. Census Bureau - American Communi...
# 43                                                NaN
#
#                                                    4   \
# 0                              Population & Geography
# 1   New York City and Greater Metropolitan Area  P...
# 2                                     Back to Section
# 3   The Estimated 2018 Population of New York City...
# 4                                   % Change  2000-10
# 5                                   % Change  2000-10
# 6                                                 NaN
# 7                                                 4.1
# 8                                                 1.8
# 9                                                 3.3
# 10                                                0.3
# 11                                                5.9
# 12                                                2.3
# 13                                                NaN
# 14                                                NaN
# 15                                                0.5
# 16                                                4.2
# 17                                                9.1
# 18                                                5.3
# 19                                                2.9
# 20                                                3.4
# 21                                                NaN
# 22                                                NaN
# 23                                                2.5
# 24                                               -1.0
# 25                                                4.4
# 26                                                4.1
# 27                                                8.1
# 28                                                2.4
# 29                                                4.9
# 30                                               13.1
# 31                                                2.4
# 32                                                8.7
# 33                                                3.5
# 34                                                2.9
# 35                                               23.9
# 36                                                4.5
# 37                                                NaN
# 38  Notes:  *Estimates are based on 2010 Census an...
# 39                                                NaN
# 40                                                NaN
# 41  View Additional Population Data for NYC:  Popu...
# 42  Source:  U.S. Census Bureau - American Communi...
# 43                                                NaN
#
#                                                    5   \
# 0                              Population & Geography
# 1   New York City and Greater Metropolitan Area  P...
# 2                                     Back to Section
# 3   The Estimated 2018 Population of New York City...
# 4                                          Estimates*
# 5                                                2013
# 6                                                 NaN
# 7                                                1422
# 8                                                2589
# 9                                                1628
# 10                                               2288
# 11                                                472
# 12                                               8399
# 13                                                NaN
# 14                                                NaN
# 15                                               1352
# 16                                                100
# 17                                                319
# 18                                               1497
# 19                                                965
# 20                                               4234
# 21                                                NaN
# 22                                                NaN
# 23                                                920
# 24                                                787
# 25                                                657
# 26                                                136
# 27                                                322
# 28                                                627
# 29                                                582
# 30                                                582
# 31                                                504
# 32                                                329
# 33                                                146
# 34                                                546
# 35                                                 56
# 36                                               6599
# 37                                                NaN
# 38  Notes:  *Estimates are based on 2010 Census an...
# 39                                                NaN
# 40                                                NaN
# 41  View Additional Population Data for NYC:  Popu...
# 42  Source:  U.S. Census Bureau - American Communi...
# 43                                                NaN
#
#                                                    6   \
# 0                              Population & Geography
# 1   New York City and Greater Metropolitan Area  P...
# 2                                     Back to Section
# 3   The Estimated 2018 Population of New York City...
# 4                                          Estimates*
# 5                                                2014
# 6                                                 NaN
# 7                                                1432
# 8                                                2603
# 9                                                1631
# 10                                               2300
# 11                                                472
# 12                                               8437
# 13                                                NaN
# 14                                                NaN
# 15                                               1355
# 16                                                 99
# 17                                                321
# 18                                               1496
# 19                                                967
# 20                                               4239
# 21                                                NaN
# 22                                                NaN
# 23                                                924
# 24                                                789
# 25                                                661
# 26                                                126
# 27                                                824
# 28                                                626
# 29                                                495
# 30                                                584
# 31                                                505
# 32                                                329
# 33                                                145
# 34                                                548
# 35                                                 56
# 36                                               6611
# 37                                                NaN
# 38  Notes:  *Estimates are based on 2010 Census an...
# 39                                                NaN
# 40                                                NaN
# 41  View Additional Population Data for NYC:  Popu...
# 42  Source:  U.S. Census Bureau - American Communi...
# 43                                                NaN
#
#                                                    7   \
# 0                              Population & Geography
# 1   New York City and Greater Metropolitan Area  P...
# 2                                     Back to Section
# 3   The Estimated 2018 Population of New York City...
# 4                                          Estimates*
# 5                                                2015
# 6                                                 NaN
# 7                                                1441
# 8                                                2611
# 9                                                1637
# 10                                               2308
# 11                                                473
# 12                                               8468
# 13                                                NaN
# 14                                                NaN
# 15                                               1355
# 16                                                 99
# 17                                                323
# 18                                               1492
# 19                                                969
# 20                                               4239
# 21                                                NaN
# 22                                                NaN
# 23                                                927
# 24                                                791
# 25                                                665
# 26                                                125
# 27                                                826
# 28                                                624
# 29                                                494
# 30                                                587
# 31                                                505
# 32                                                330
# 33                                                143
# 34                                                550
# 35                                                 55
# 36                                               6622
# 37                                                NaN
# 38  Notes:  *Estimates are based on 2010 Census an...
# 39                                                NaN
# 40                                                NaN
# 41  View Additional Population Data for NYC:  Popu...
# 42  Source:  U.S. Census Bureau - American Communi...
# 43                                                NaN
#
#                                                    8   \
# 0                              Population & Geography
# 1   New York City and Greater Metropolitan Area  P...
# 2                                     Back to Section
# 3   The Estimated 2018 Population of New York City...
# 4                                          Estimates*
# 5                                                2016
# 6                                                 NaN
# 7                                                1445
# 8                                                2611
# 9                                                1636
# 10                                               2309
# 11                                                474
# 12                                               8476
# 13                                                NaN
# 14                                                NaN
# 15                                               1356
# 16                                                 99
# 17                                                324
# 18                                               1487
# 19                                                971
# 20                                               4236
# 21                                                NaN
# 22                                                NaN
# 23                                                929
# 24                                                793
# 25                                                669
# 26                                                125
# 27                                                826
# 28                                                623
# 29                                                494
# 30                                                591
# 31                                                504
# 32                                                330
# 33                                                142
# 34                                                553
# 35                                                 55
# 36                                               6634
# 37                                                NaN
# 38  Notes:  *Estimates are based on 2010 Census an...
# 39                                                NaN
# 40                                                NaN
# 41  View Additional Population Data for NYC:  Popu...
# 42  Source:  U.S. Census Bureau - American Communi...
# 43                                                NaN
#
#                                                    9   \
# 0                              Population & Geography
# 1   New York City and Greater Metropolitan Area  P...
# 2                                     Back to Section
# 3   The Estimated 2018 Population of New York City...
# 4                                          Estimates*
# 5                                                2017
# 6                                                 NaN
# 7                                                1440
# 8                                                2596
# 9                                                1630
# 10                                               2297
# 11                                                476
# 12                                               8438
# 13                                                NaN
# 14                                                NaN
# 15                                               1358
# 16                                                 99
# 17                                                325
# 18                                               1484
# 19                                                969
# 20                                               4234
# 21                                                NaN
# 22                                                NaN
# 23                                                934
# 24                                                796
# 25                                                673
# 26                                                125
# 27                                                828
# 28                                                622
# 29                                                494
# 30                                                595
# 31                                                504
# 32                                                330
# 33                                                141
# 34                                                555
# 35                                                 56
# 36                                               6653
# 37                                                NaN
# 38  Notes:  *Estimates are based on 2010 Census an...
# 39                                                NaN
# 40                                                NaN
# 41  View Additional Population Data for NYC:  Popu...
# 42  Source:  U.S. Census Bureau - American Communi...
# 43                                                NaN
#
#                                                    10  11
# 0                              Population & Geography NaN
# 1   New York City and Greater Metropolitan Area  P... NaN
# 2                                     Back to Section NaN
# 3   The Estimated 2018 Population of New York City... NaN
# 4                                          Estimates* NaN
# 5                                                2018 NaN
# 6                                                 NaN NaN
# 7                                                1432 NaN
# 8                                                2583 NaN
# 9                                                1629 NaN
# 10                                               2279 NaN
# 11                                                476 NaN
# 12                                               8399 NaN
# 13                                                NaN NaN
# 14                                                NaN NaN
# 15                                               1358 NaN
# 16                                                 99 NaN
# 17                                                326 NaN
# 18                                               1481 NaN
# 19                                                968 NaN
# 20                                               4232 NaN
# 21                                                NaN NaN
# 22                                                NaN NaN
# 23                                                937 NaN
# 24                                                800 NaN
# 25                                                676 NaN
# 26                                                125 NaN
# 27                                                830 NaN
# 28                                                621 NaN
# 29                                                494 NaN
# 30                                                602 NaN
# 31                                                503 NaN
# 32                                                331 NaN
# 33                                                141 NaN
# 34                                                558 NaN
# 35                                                 56 NaN
# 36                                               6673 NaN
# 37                                                NaN NaN
# 38  Notes:  *Estimates are based on 2010 Census an... NaN
# 39                                                NaN NaN
# 40                                                NaN NaN
# 41  View Additional Population Data for NYC:  Popu... NaN
# 42  Source:  U.S. Census Bureau - American Communi... NaN
# 43                                                NaN NaN

# %% [markdown]
# <h2><a id = "item2"></a> Acquiring Foursquare data </h2> <a href = "#top"> back to top </a>

# %% [markdown]
# #### Toronto:

# %%
CLIENT_ID = 'NA0Q3HAIZG5G1XDGDI5ZCGQPBSNEP4SGYF5B0ULTZBDZHIOV' # your Foursquare ID
CLIENT_SECRET = 'HNVACZRJK5KNIEWX0IBRFZI0U3AG5NH1MUSWVUXBDWBFTU1J' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: NA0Q3HAIZG5G1XDGDI5ZCGQPBSNEP4SGYF5B0ULTZBDZHIOV
# CLIENT_SECRET:HNVACZRJK5KNIEWX0IBRFZI0U3AG5NH1MUSWVUXBDWBFTU1J

# %%
# latitude and longitude of Toronto
tor_name = 'Toronto'
tor_lat = 43.6532
tor_lon = -79.3832
print('Latitude and longitude values of {} are {}, {}.'.format(tor_name, 
                                                               tor_lat, 
                                                               tor_lon))
# Out:
# Latitude and longitude values of Toronto are 43.6532, -79.3832.

# %% [markdown]
# ### Explore venues in Toronto within 500 m radius

# %%
LIMIT = 100
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    tor_lat, 
    tor_lon,
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=NA0Q3HAIZG5G1XDGDI5ZCGQPBSNEP4SGYF5B0ULTZBDZHIOV&client_secret=HNVACZRJK5KNIEWX0IBRFZI0U3AG5NH1MUSWVUXBDWBFTU1J&v=20180605&ll=43.6532,-79.3832&radius=500&limit=100'

# %%
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# results

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng', 'venue.location.postalCode']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# c:\users\jothika pc\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                       name      categories        lat        lng postalCode
# 0         Downtown Toronto    Neighborhood  43.653232 -79.385296        NaN
# 1   Nathan Phillips Square           Plaza  43.652270 -79.383516    M5H 2N1
# 2                   Indigo       Bookstore  43.653515 -79.380696    M5B 2H1
# 3                     LUSH  Cosmetics Shop  43.653557 -79.380400    M5B 2H1
# 4  CF Toronto Eaton Centre   Shopping Mall  43.654540 -79.380677    M5B 2H1

# %% [markdown]
# Can extract postal codes of each venue (except those that dont have one)

# %% [markdown]
# Can scrape this site to get boroughs of each postal code area and then merge the two tables together

# %%
postal_codes = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
postal_codes = postal_codes[0]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-1db2e7397ca4> in <module>
# ----> 1 postal_codes = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
#       2 postal_codes = postal_codes[0]
#
# c:\users\jothika pc\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# c:\users\jothika pc\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     889     retained = None
#     890     for flav in flavor:
# --> 891         parser = _parser_dispatch(flav)
#     892         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     893
#
# c:\users\jothika pc\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\html.py in _parser_dispatch(flavor)
#     846     else:
#     847         if not _HAS_LXML:
# --> 848             raise ImportError("lxml not found, please install it")
#     849     return _valid_parsers[flavor]
#     850
#
# ImportError: lxml not found, please install it

# %%
postal_codes.dropna(inplace = True)

# %%
postal_codes

# %%
# codes = nearby_venues['postalCode']

# %%
# split the postal code values to we just get the area code
for i in range(len(codes)):
    if not pd.isnull(codes[i]):
        codes[i] = codes[i].split()[0]

# %%
len(codes)

# %%
# postal_codes.set_index('Postal Code',inplace = True)

# %% [markdown]
# Create an array to store boroughs

# %% [markdown]
# #### This function takes a dataframe containing Foursquare data and will find the Borough location of each venue using its assigned postal code

# %%
def get_postal_borough(dataframe):
    borough = []
    codes = dataframe['postalCode']
    # split the postal code values to we just get the area code
    for i in range(len(codes)):
        if not pd.isnull(codes[i]):
            codes[i] = codes[i].split()[0]
    
    
    for i in range(len(codes)):
        if not pd.isnull(codes[i]) and codes[i] in postal_codes.index:
            borough.append(postal_codes.at[codes[i],'Borough'])
        else:
            borough.append('not assigned')
    return borough

# %% [markdown]
# Add this array as a column to the dataframe

# %%
nearby_venues['Borough'] = get_postal_borough(nearby_venues)

# %%
nearby_venues.head(10)

# %% [markdown]
# <h2><a id = "item3"></a> Map of Toronto </h2><a href = "#top"> back to top </a>

# %%
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library
print('Folium imported')

# %%
map_toronto = folium.Map(location=[tor_lat, tor_lon], zoom_start=10)

for lat, lng, postal, borough, name in zip(nearby_venues['lat'], nearby_venues['lng'], nearby_venues['postalCode'],nearby_venues['Borough'], nearby_venues['name']):
    label = '{},{}'.format(name,borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto

# %% [markdown]
# <h2><a id = "item4"></a> Foursquare data for each Borough in Toronto</h2><a href = "#top"> back to top </a>

# %% [markdown]
# ### I want to repeat this process for every borough in Toronto

# %%
unique_boroughs = postal_codes['Borough'].drop_duplicates()

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# %%
address = 'Etobicoke, Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates are {}, {}.'.format(latitude, longitude))

# %% [markdown]
# #### This function uses the geocoders api to retrieve the coordinates of each borough in Toronto

# %%
def get_borough_coords():
    borough_coords = []
    for i in range(len(unique_boroughs)):
        address = unique_boroughs[i]+', Toronto'

        geolocator = Nominatim(user_agent="ny_explorer")
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
#         print('The geograpical coordinates of ' + unique_boroughs[i] + ' are {}, {}.'.format(latitude, longitude))
        borough_coords.append([unique_boroughs[i],latitude,longitude])
        
    return borough_coords

# %%
# borough_coords = get_borough_coords()

# %%
borough_coords

# %% [markdown]
# The geocoders data returned the same coordinates for East Toronto, West Toronto and Central Toronto. We may decide to drop the duplicate coordinates later on and just focus on one of those three areas.
# Lets turn this into a dataframe.

# %%
coords_df = pd.DataFrame(borough_coords, columns = ['Borough','Lat','Lon'])
coords_df.drop_duplicates(subset = ['Lat','Lon'],inplace = True)
coords_df.reset_index(inplace = True)
coords_df.drop(columns = ['index'],inplace = True)
coords_df

# %%
def get_4square_for_boroughs():
    i = 6

    lat = coords_df.loc[i,'Lat']
    lon = coords_df.loc[i,'Lon']
    LIMIT = 100
    radius = 500
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        lon,
        radius, 
        LIMIT)
#         url # display URL
#     return url
    results = requests.get(url).json()
    results
    venues = results['response']['groups'][0]['items']
    
    df = json_normalize(venues) # flatten JSON

    # filter columns
    filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng', 'venue.location.postalCode']
    df =df.loc[:, filtered_columns]

    # filter the category for each row
    df['venue.categories'] = df.apply(get_category_type, axis=1)

    # clean columns
    df.columns = [col.split(".")[-1] for col in df.columns]
    
    # create a Borough column using the get_postal_borough funtion
    df['Borough'] = get_postal_borough(df)
    return df

# %%
# url = get_4square_for_boroughs()

# %%
# results = requests.get(url).json()

# %%
local_venues = get_4square_for_boroughs()

# %%
local_venues2 = get_4square_for_boroughs()

# %%
local_venues.head(10)

# %% [markdown]
# This is how we can merge multiple dataframes into one master frame

# %%
master_df = pd.DataFrame(columns = ['name','categories','lat','lng','postalCode','Borough'])

# %%
frames = [local_venues,local_venues2]
master_df = pd.concat(frames)

# %%
master_df

# %% [markdown]
# #### This function creates a dataframe for each borough with the available information retrieved from the Foursquare api, and returns a merged dataframe containing information for each borough

# %%
def get_4square_for_boroughs():
    i = 0
    frames = []
    while i < coords_df.shape[0]:
        lat = coords_df.loc[i,'Lat']
        lon = coords_df.loc[i,'Lon']
        LIMIT = 100
        radius = 500
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lon,
            radius, 
            LIMIT)
    #         url # display URL
    #     return url
        results = requests.get(url).json()
        venues = results['response']['groups'][0]['items']

        df = json_normalize(venues) # flatten JSON

        # filter columns
        filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng', 'venue.location.postalCode']
        df =df.loc[:, filtered_columns]

        # filter the category for each row
        df['venue.categories'] = df.apply(get_category_type, axis=1)

        # clean columns
        df.columns = [col.split(".")[-1] for col in df.columns]

        # create a Borough column using the get_postal_borough funtion
        df['Borough'] = get_postal_borough(df)
        frames.append(df)
        i+=1
    return pd.concat(frames)

# %%
master_df = get_4square_for_boroughs()

# %%
 master_df.reset_index(inplace = True)

# %%
master_df.head()

# %% [markdown]
# Now we have the venue information that was available from each Borough.  There are many venues that are not assigned a Borough, we might drop these values later.
# We can also see that a large majority of these venues are coming from Downtown Toronto.

# %% [markdown]
# <h2><a id = "item5"></a> Let's Create a Master Map </h2> <a href = '#top'> back to top </a>

# %%
master_map = folium.Map(location=[tor_lat, tor_lon], zoom_start=12)

for lat, lng, postal, borough, name in zip(master_df['lat'], master_df['lng'], master_df['postalCode'],master_df['Borough'], master_df['name']):
    label = '{},{}'.format(name,borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(master_map)  
    
master_map

# %% [markdown]
# Now we can view the venues located in each borough
